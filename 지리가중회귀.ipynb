# %%
from geoband.API import *
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")
import geopandas as gpd
import pandas as pd
import json
from pandas import json_normalize
import pandas as pd
import folium
from folium.plugins import MarkerCluster
from geoband.API import *
import geopandas as gpd
import warnings
warnings.filterwarnings("ignore")
from shapely.geometry import Point, Polygon
import matplotlib.pyplot as plt
import folium
from folium import Choropleth, Circle, Marker
from folium.plugins import HeatMap, MarkerCluster
from geopandas import GeoDataFrame
from folium import Choropleth
import matplotlib
from datetime import datetime 
# GetCompasData로 주피터 노트북 경로에 파일 저장
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import Point, Polygon, LineString
from fiona.crs import from_string
matplotlib.rcParams['font.family']="Malgun Gothic"

# %%
선용=pd.read_csv("전처리완료_선용.csv")
나연=pd.read_csv("전처리완료_나연.csv")

# %%
df=pd.merge(선용, 나연, how='inner', on='관할경찰서')
df.to_csv("4개시도_전처리완료.csv", index=False)
df
# Out:
#        관할경찰서       건물연한     건물노후도   단독주택  공동주택  제2종근린생활시설  제1종근린생활시설    공장  \
# 0    마산동부경찰서  34.221704  3.520023  14699  1126       1355       1962   762
# 1    마산중부경찰서  27.137778  3.040000   8489   591       1234       1735   387
# 2    서울강남경찰서  26.375468  3.038648   3533  2509       3606       1761     0
# 3    서울강동경찰서  26.086668  3.049578   9171  5101       1465       1531     5
# 4    서울강북경찰서  31.807006  3.248836  16671  5554       1340       2191     8
# 5    서울강서경찰서  27.005737  3.041989  10355  7842       1934       1983    88
# 6    서울관악경찰서  26.835200  3.006179  18389  6148       2990       2267     4
# 7    서울광진경찰서  27.653790  3.069064  14874  4733       1861       2053    11
# 8    서울구로경찰서  29.174967  3.178105   9876  4768       1241       1715   255
# 9    서울금천경찰서  28.568851  3.189752   8022  2849       1063        952   516
# 10  서울남대문경찰서  48.613572  3.653799    506   127        529        491     5
# 11   서울노원경찰서  26.825396  3.068385   4856  3674       1069       1367     8
# 12   서울도봉경찰서  29.360346  3.205585   7981  4011        899       1499    36
# 13  서울동대문경찰서  37.202485  3.507949  17999  2709       2227       4145    73
# 14   서울동작경찰서  29.102798  3.128232  13708  5005       1540       1794     6
# 15   서울마포경찰서  28.576875  3.024246   9270  5171       3885       2097    15
# 16   서울방배경찰서  28.402256  3.141340   3026  2569        920        595     0
# 17  서울서대문경찰서  32.421483  3.247860  10700  4466       1589       1958     9
# 18   서울서부경찰서  28.886993  3.110492   7042  4775        821        996     8
# 19   서울서초경찰서  26.392647  3.065458   2863  2385       2353       1008     6
# 20   서울성동경찰서  34.392616  3.445504   9389  2135       1637       2122   597
# 21   서울성북경찰서  32.030537  3.160636   9079  2760       1457       1377     3
# 22   서울송파경찰서  24.555654  2.934221   7370  9439       2400       2209     0
# 23   서울수서경찰서  27.759066  3.151451   2824  2802       1699        803     0
# 24   서울양천경찰서  28.144378  3.214480   7220  5578       1303       1551    15
# 25  서울영등포경찰서  32.267852  3.313996  14066  2435       2271       3523   259
# 26   서울용산경찰서  37.384906  3.434009  11825  3374       2503       1834    64
# 27   서울은평경찰서  28.529883  3.053410   6905  4899        856        853     1
#     건설이후(일)  편의점  지구대인원
# 0   1507340  198    185
# 1   1126729  148    142
# 2   1182124  396    421
# 3   1788883  349    393
# 4   1049841  216    347
# 5   2598175  501    500
# 6   1623401  418    493
# 7   1348329  371    380
# 8   2151029  317     69
# 9    879015  267    274
# 10   117954  125    186
# 11  4172851  307    415
# 12  2083406  227    273
# 13  1598050  335    429
# 14  1369672  304    353
# 15  1881650  391     40
# 16   765256  126     40
# 17  1279867  264     39
# 18   890617  152    458
# 19  1779268  282    141
# 20  1708075  261     52
# 21  1276953  236    322
# 22  3840343  435    221
# 23  1689143  344    339
# 24  2884386  249    320
# 25  2144332  475    252
# 26  1129821  248    538
# 27  1050153  181    312
# 28   346389  156    376
# 29   798336  141    513
# 30  1649822  277     39
# 31   456747  193    343
# 32   211143  109    203
# 33  3212435  507     64
# 34  1409157  216    285
# 35  2393629  310    176
# 36  2841687  336    406
# 37  1413394  191    236
# 38  1305352  199     52
# 39  1737015  238    213
#
# [40 rows x 49 columns]

# %%
suwon_112 = pd.read_csv('1.수원시_112신고이력(격자_관할경계매핑).csv')
others_112 = pd.read_csv('3.3개시도_112신고이력(관할경계매핑).csv')

# %%
# 신고데이터를 y로 합체
suwon_112_group=suwon_112.groupby(['psname']).count()
suwon_112_group=pd.DataFrame(suwon_112_group['case_type'])
suwon_112_group.rename(columns={'case_type':'cnt'}, inplace=True)
suwon_112_group.reset_index(inplace=True)

others_112_group=others_112.groupby(['psname']).count()
others_112_group=pd.DataFrame(others_112_group['case_type'])
others_112_group.rename(columns={'case_type':'cnt'}, inplace=True)
others_112_group.reset_index(inplace=True)


df_y=pd.concat([suwon_112_group, others_112_group], axis=0)
df_y.sort_values(by='psname', inplace=True)
df_y.rename(columns={'psname':'관할경찰서', 'cnt':'신고건수'}, inplace=True)
df_y.reset_index(inplace=True)
df_y.drop(['index'],axis=1, inplace=True)
df_y
# Out:
#        관할경찰서    신고건수
# 0    마산동부경찰서   37637
# 1    마산중부경찰서   29444
# 2    서울강남경찰서   90924
# 3    서울강동경찰서   80040
# 4    서울강북경찰서   67416
# 5    서울강서경찰서  106612
# 6    서울관악경찰서   97099
# 7    서울광진경찰서   79907
# 8    서울구로경찰서   79089
# 9    서울금천경찰서   57843
# 10  서울남대문경찰서   21122
# 11   서울노원경찰서   82461
# 12   서울도봉경찰서   49383
# 13  서울동대문경찰서   77654
# 14   서울동작경찰서   65615
# 15   서울마포경찰서   91721
# 16   서울방배경찰서   23817
# 17  서울서대문경찰서   61187
# 18   서울서부경찰서   41620
# 19   서울서초경찰서   73732
# 20   서울성동경찰서   53918
# 21   서울성북경찰서   37230
# 22   서울송파경찰서  114438
# 23   서울수서경찰서   67262
# 24   서울양천경찰서   66235
# 25  서울영등포경찰서  103655
# 26   서울용산경찰서   61657
# 27   서울은평경찰서   43412
# 28   서울종로경찰서   37285
# 29   서울종암경찰서   31123
# 30   서울중랑경찰서   82258
# 31   서울중부경찰서   37557
# 32   서울혜화경찰서   29195
# 33   수원남부경찰서   89255
# 34   수원서부경찰서   60672
# 35   수원중부경찰서   73837
# 36     진주경찰서   53539
# 37     진해경찰서   27464
# 38   창원서부경찰서   34805
# 39   창원중부경찰서   42293

# %%
from geoband.API import *
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import folium
import json
import geopandas as gpd
import os
import pydeck as pdk
import shapefile

# %%
#변수선택법

import time
import itertools

#회귀분석

import statsmodels.api as sm
from statsmodels.sandbox.regression.predstd import wls_prediction_std
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

#공간회귀분석

import pysal
import libpysal
from esda.moran import Moran
from esda.moran import Moran_Local
from libpysal.weights import Queen, Rook, KNN, DistanceBand, Kernel
from esda.getisord import G
from esda.moran import Moran
from spreg import OLS, ML_Lag, ML_Error, GM_Lag, GM_Error, TSLS

#정규성검정

from scipy.stats import shapiro

#다중공선성 체크

from statsmodels.stats.outliers_influence import variance_inflation_factor


#지리적가중회귀분석

from mgwr.gwr import GWR, MGWR
from mgwr.sel_bw import Sel_BW
from mgwr.utils import compare_surfaces, truncate_colormap

# %%
def processSubset(X,y,feature_set):
    model = sm.OLS(y,X[list(feature_set)]) # Modeling
    regr = model.fit() # model fitting
    AIC = regr.aic # model's AIC
    return {"model" : regr, "AIC" : AIC}

# %%
#전진선택법

def forward(X,y,predictors):

    # predictor - 현재 선택되어있는 변수
    # 데이터 변수들이 미리정의된 predictors에 있는지 없는지 확인 및 분류
    
    remaining_predictors = [p for p in X.columns.difference(['const']) if p not in predictors]
    tic = time.time()
    results = []
    for p in remaining_predictors :
        results.append(processSubset(X=X,y=y,feature_set=predictors+[p]+['const']))
    
    models = pd.DataFrame(results)
    
    best_model = models.loc[models['AIC'].argmin()] #AIC가 가장 낮은 모델을 선택
    toc = time.time()
    print("Processed ",models.shape[0], "models on", len(predictors)+1, "predictors in", (toc-tic))
    print("Selected predictors:",best_model["model"].model.exog_names,"AIC: ",best_model[0])
    return best_model
    
#전진선택법 모델

def forward_model(X,y):

    Fmodels = pd.DataFrame(columns=["AIC","model"])
    tic = time.time()
     
    predictors = []
    
    for i in range(1,len(X.columns.difference(['const']))+1):
        Forward_result = forward(X=X,y=y,predictors=predictors)
        if i > 1:
            if Forward_result["AIC"] > Fmodel_before:
                break
        Fmodels.loc[i] = Forward_result
        predictors = Fmodels.loc[i]["model"].model.exog_names
        Fmodel_before = Fmodels.loc[i]["AIC"]
        predictors = [k for k in predictors if k != 'const']
    toc = time.time()
    print("Total elapsed time:",(toc-tic), "seconds.")
    
    return (Fmodels['model'][len(Fmodels['model'])])

# %%
#후진제거법

def backward(X,y,predictors):
    tic= time.time()
    results = []
    
    for combo in itertools.combinations(predictors, len(predictors) - 1):
        results.append(processSubset(X=X,y=y,feature_set=list(combo)+['const']))
    models = pd.DataFrame(results)
    
    best_model = models.loc[models['AIC'].argmin()]    # 가장 낮은 AIC를 가진 모델을 선택
    toc = time.time()
    
    print("Processed ",models.shape[0], "models on", len(predictors) - 1, "predictors in",(toc-tic))
    print("Selected predictors:",best_model['model'].model.exog_names,' AIC:',best_model[0])
    return best_model
    
def backward_model(X,y) :
    Bmodels = pd.DataFrame(columns=["AIC","model"], index = range(1,len(X.columns)))
    tic = time.time()
    predictors = X.columns.difference(['const'])
    Bmodel_before = processSubset(X,y,predictors)['AIC']
    while (len(predictors) > 1):
        Backward_result = backward(X=X, y= y, predictors=predictors)
        if Backward_result['AIC'] > Bmodel_before :
            break
        Bmodels.loc[len(predictors) -1] = Backward_result
        predictors = Bmodels.loc[len(predictors) - 1]['model'].model.exog_names
        Bmodel_before = Backward_result["AIC"]
        predictors = [k for k in predictors if k != 'const']

    toc = time.time()
    print("Total elapsed time:",(toc-tic),"seconds.")
    return Bmodels["model"].dropna().iloc[0]

# %%
#변수선택법

def Stepwise_model(X,y):
    Stepmodels = pd.DataFrame(columns = ["AIC","model"])
    tic = time.time()
    predictors = []
    Smodel_before = processSubset(X,y,predictors + ['const'])['AIC']
    
    
    for i in range(1,len(X.columns.difference(['const']))+1) :
        Forward_result = forward(X=X,y=y,predictors = predictors) # constant added
        print('forward')
        Stepmodels.loc[i] = Forward_result
        predictors = Stepmodels.loc[i]["model"].model.exog_names
        predictors = [k for k in predictors if k != 'const']
        Backward_result = backward(X=X,y=y,predictors = predictors)
        if Backward_result["AIC"] < Forward_result["AIC"]:
            Stepmodels.loc[i] = Backward_result
            predictors = Stepmodels.loc[i]["model"].model.exog_names
            Smodel_before = Stepmodels.loc[i]["AIC"]
            predictors = [k for k in predictors if k != "const"]
            print('backward')
        if Stepmodels.loc[i]["AIC"] > Smodel_before:
            break
        else :
            Smodel_before = Stepmodels.loc[i]["AIC"]
    toc = time.time()
    print("Total elapsed time:",(toc-tic),"seconds.")
    return (Stepmodels["model"][len(Stepmodels["model"])])

# %% [markdown]
# ## 시작

# %%
X=df.drop(['관할경찰서', '지역'], axis=1)
y=pd.DataFrame(df_y.loc[:, '신고건수'])

# %%
X
# Out:
#          건물연한     건물노후도   단독주택  공동주택  제2종근린생활시설  제1종근린생활시설    공장  업무시설  \
# 0   34.221704  3.520023  14699  1126       1355       1962   762   101
# 1   27.137778  3.040000   8489   591       1234       1735   387    88
# 2   26.375468  3.038648   3533  2509       3606       1761     0   877
# 3   26.086668  3.049578   9171  5101       1465       1531     5   210
# 4   31.807006  3.248836  16671  5554       1340       2191     8   102
# 5   27.005737  3.041989  10355  7842       1934       1983    88   291
# 6   26.835200  3.006179  18389  6148       2990       2267     4   536
# 7   27.653790  3.069064  14874  4733       1861       2053    11   226
# 8   29.174967  3.178105   9876  4768       1241       1715   255   213
# 9   28.568851  3.189752   8022  2849       1063        952   516   200
# 10  48.613572  3.653799    506   127        529        491     5   293
# 11  26.825396  3.068385   4856  3674       1069       1367     8    94
# 12  29.360346  3.205585   7981  4011        899       1499    36    90
# 13  37.202485  3.507949  17999  2709       2227       4145    73   229
# 14  29.102798  3.128232  13708  5005       1540       1794     6   116
# 15  28.576875  3.024246   9270  5171       3885       2097    15   483
# 16  28.402256  3.141340   3026  2569        920        595     0   163
# 17  32.421483  3.247860  10700  4466       1589       1958     9   153
# 32     114    76  ...   4    11       0        0     0       0      0
# 33     292   116  ...  43   105       8       16     2       0      2
# 34     180   149  ...  25    45       4        9     0       0      1
# 35     366    64  ...  35    66       2        6     2       3      0
# 36     525  2039  ...  42    62       6        4     2       4      0
# 37     102   145  ...  20    45      12        5     0       0      2
# 38     143   923  ...  26    62       4        2     0       0      2
# 39     276   134  ...  22    40       3        0     1       0      3
#
#     건설이후(일)  편의점  지구대인원
# 0   1507340  198    185
# 1   1126729  148    142
# 2   1182124  396    421
# 3   1788883  349    393
# 4   1049841  216    347
# 5   2598175  501    500
# 6   1623401  418    493
# 7   1348329  371    380
# 8   2151029  317     69
# 9    879015  267    274
# 10   117954  125    186
# 11  4172851  307    415
# 12  2083406  227    273
# 13  1598050  335    429
# 14  1369672  304    353
# 15  1881650  391     40
# 16   765256  126     40
# 17  1279867  264     39
# 18   890617  152    458
# 19  1779268  282    141
# 20  1708075  261     52
# 21  1276953  236    322
# 22  3840343  435    221
# 23  1689143  344    339
# 24  2884386  249    320
# 25  2144332  475    252
# 26  1129821  248    538
# 27  1050153  181    312
# 28   346389  156    376
# 29   798336  141    513
# 30  1649822  277     39
# 31   456747  193    343
# 32   211143  109    203
# 33  3212435  507     64
# 34  1409157  216    285
# 35  2393629  310    176
# 36  2841687  336    406
# 37  1413394  191    236
# 38  1305352  199     52
# 39  1737015  238    213
#
# [40 rows x 47 columns]

# %%
#전체 독립변수를 대상으로 다중공선성 확인

vif_acc_risk = pd.DataFrame()
vif_acc_risk['VIF Factor'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif_acc_risk['features'] = X.columns
vif_acc_risk
# Out:
#     VIF Factor        features
# 0          inf            건물연한
# 1          inf           건물노후도
# 2          inf            단독주택
# 3          inf            공동주택
# 4          inf       제2종근린생활시설
# 5          inf       제1종근린생활시설
# 6          inf              공장
# 7          inf            업무시설
# 8          inf          교육연구시설
# 9          inf            창고시설
# 10         inf           노유자시설
# 11         inf            숙박시설
# 12         inf          생활관련시설
# 13         inf            유흥업소
# 14         inf             보안등
# 15         inf           안전비상벨
# 16         inf       안전비상벨_가로변
# 17         inf        안전비상벨_공원
# 18         inf       안전비상벨_화장실
# 19         inf        CCTV설치대수
# 20         inf   CCTV설치목적_생활방범
# 21         inf  CCTV설치목적_어린이보호
# 22         inf   CCTV설치목적_교통단속
# 23         inf  CCTV설치목적_쓰레기단속
# 24         inf   CCTV설치목적_재난재해
# 25         inf            전체공원
# 26         inf           어린이공원
# 27         inf            근린공원
# 28         inf             소공원
# 29         inf            문화공원
# 30         inf            역사공원
# 31         inf            체육공원
# 32         inf            경찰관서
# 33         inf         어린이놀이시설
# 34         inf            어린이집
# 35         inf            주택단지
# 36         inf             유치원
# 37         inf              학교
# 38         inf            도시공원
# 39         inf          식품접객업소
# 40         inf         놀이제공영업소
# 41         inf            종교시설
# 42         inf          아동복지시설
# 43         inf           대규모점포
# 44         inf         건설이후(일)
# 45         inf             편의점
# 46         inf           지구대인원

# %% [markdown]
# ## -> 노답이라 일단 변수선택부터!

# 33  0.50   0.000  0.250  0.763147  1.000000  0.050100
# 34  0.00   0.000  0.125  0.318431  0.268844  0.492986
# 35  0.50   0.375  0.000  0.561216  0.505025  0.274549
# 36  0.50   0.500  0.000  0.671714  0.570352  0.735471
# 37  0.00   0.000  0.250  0.319475  0.206030  0.394790
# 38  0.00   0.000  0.250  0.292831  0.226131  0.026052
# 39  0.25   0.000  0.375  0.399285  0.324121  0.348697
#
# [40 rows x 48 columns]

# %%
step_best_model_ctc = Stepwise_model(scaled_X, y)
# Out:
# Processed  47 models on 1 predictors in 0.07104611396789551
# Selected predictors: ['편의점', 'const'] AIC:  <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f4496f09828>
# forward
# Processed  1 models on 0 predictors in 0.0035202503204345703
# Selected predictors: ['const']  AIC: <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f447c0a83c8>
# Processed  46 models on 2 predictors in 0.08447384834289551
# Selected predictors: ['편의점', '공동주택', 'const'] AIC:  <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f4496efa7f0>
# forward
# Processed  2 models on 1 predictors in 0.005889892578125
# Selected predictors: ['편의점', 'const']  AIC: <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f4496f09a58>
# Processed  45 models on 3 predictors in 0.0789799690246582
# Selected predictors: ['편의점', '공동주택', '업무시설', 'const'] AIC:  <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f4496f12fd0>
# forward
# Processed  3 models on 2 predictors in 0.007334470748901367
# Selected predictors: ['편의점', '공동주택', 'const']  AIC: <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f4496f12240>
# Processed  44 models on 4 predictors in 0.0847008228302002
# Selected predictors: ['편의점', '공동주택', '업무시설', 'CCTV설치목적_재난재해', 'const'] AIC:  <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f4496f12668>
# forward
# Processed  4 models on 3 predictors in 0.008608102798461914
# Selected predictors: ['편의점', '공동주택', '업무시설', 'const']  AIC: <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f4496f09c88>
# Processed  43 models on 5 predictors in 0.0728003978729248
# Selected predictors: ['편의점', '공동주택', '업무시설', 'CCTV설치목적_재난재해', '건물노후도', 'const'] AIC:  <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f4496f09dd8>
# forward
# Processed  5 models on 4 predictors in 0.009651660919189453
# Selected predictors: ['편의점', '공동주택', 'CCTV설치목적_재난재해', '건물노후도', 'const']  AIC: <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f4496f12978>
# Processed  42 models on 6 predictors in 0.07164525985717773
# Selected predictors: ['편의점', '공동주택', '업무시설', 'CCTV설치목적_재난재해', '건물노후도', '생활관련시설', 'const'] AIC:  <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f4496efa9e8>
# forward
# Processed  6 models on 5 predictors in 0.012603521347045898
# Selected predictors: ['편의점', '공동주택', '업무시설', 'CCTV설치목적_재난재해', '건물노후도', 'const']  AIC: <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f4496f03080>
# Processed  41 models on 7 predictors in 0.07357501983642578
# Selected predictors: ['편의점', '공동주택', '업무시설', 'CCTV설치목적_재난재해', '건물노후도', '생활관련시설', '창고시설', 'const'] AIC:  <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f4496f123c8>
# forward
# Processed  7 models on 6 predictors in 0.01195836067199707
# Selected predictors: ['편의점', '공동주택', '업무시설', 'CCTV설치목적_재난재해', '생활관련시설', '창고시설', 'const']  AIC: <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f447c0a8a90>
# Processed  40 models on 8 predictors in 0.06858706474304199
# Selected predictors: ['편의점', '공동주택', '업무시설', 'CCTV설치목적_재난재해', '건물노후도', '생활관련시설', '창고시설', '노유자시설', 'const'] AIC:  <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f4496f09588>
# forward
# Processed  8 models on 7 predictors in 0.01345062255859375
# Selected predictors: ['편의점', '업무시설', 'CCTV설치목적_재난재해', '건물노후도', '생활관련시설', '창고시설', '노유자시설', 'const']  AIC: <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f4496f03cf8>
# backward
# Processed  40 models on 8 predictors in 0.06744742393493652
# Selected predictors: ['편의점', '업무시설', 'CCTV설치목적_재난재해', '건물노후도', '생활관련시설', '창고시설', '노유자시설', 'CCTV설치목적_쓰레기단속', 'const'] AIC:  <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f4496f03668>
# forward
# Processed  8 models on 7 predictors in 0.012911319732666016
# Selected predictors: ['편의점', '업무시설', 'CCTV설치목적_재난재해', '생활관련시설', '창고시설', '노유자시설', 'CCTV설치목적_쓰레기단속', 'const']  AIC: <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f4496f128d0>
# backward
# Processed  40 models on 8 predictors in 0.07382631301879883
# Selected predictors: ['편의점', '업무시설', 'CCTV설치목적_재난재해', '생활관련시설', '창고시설', '노유자시설', 'CCTV설치목적_쓰레기단속', '제2종근린생활시설', 'const'] AIC:  <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f4496f030b8>
# forward
# Processed  8 models on 7 predictors in 0.015418291091918945
# Selected predictors: ['편의점', 'CCTV설치목적_재난재해', '생활관련시설', '창고시설', '노유자시설', 'CCTV설치목적_쓰레기단속', '제2종근린생활시설', 'const']  AIC: <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f4496f03358>
# backward
# Processed  40 models on 8 predictors in 0.07263398170471191
# Selected predictors: ['편의점', 'CCTV설치목적_재난재해', '생활관련시설', '창고시설', '노유자시설', 'CCTV설치목적_쓰레기단속', '제2종근린생활시설', '유치원', 'const'] AIC:  <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f4496f12da0>
# forward
# Processed  8 models on 7 predictors in 0.013892173767089844
# Selected predictors: ['편의점', 'CCTV설치목적_재난재해', '창고시설', '노유자시설', 'CCTV설치목적_쓰레기단속', '제2종근린생활시설', '유치원', 'const']  AIC: <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f447c0a8f98>
# backward
# Processed  40 models on 8 predictors in 0.07792544364929199
# Selected predictors: ['편의점', 'CCTV설치목적_재난재해', '창고시설', '노유자시설', 'CCTV설치목적_쓰레기단속', '제2종근린생활시설', '유치원', '놀이제공영업소', 'const'] AIC:  <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f4496efae48>
# forward
# Processed  8 models on 7 predictors in 0.013430356979370117
# Selected predictors: ['편의점', 'CCTV설치목적_재난재해', '창고시설', '노유자시설', 'CCTV설치목적_쓰레기단속', '제2종근린생활시설', '유치원', 'const']  AIC: <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f4496f039b0>
# Processed  39 models on 9 predictors in 0.05811429023742676
# Selected predictors: ['편의점', 'CCTV설치목적_재난재해', '창고시설', '노유자시설', 'CCTV설치목적_쓰레기단속', '제2종근린생활시설', '유치원', '놀이제공영업소', '학교', 'const'] AIC:  <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f4496f0d2b0>
# forward
# Processed  9 models on 8 predictors in 0.016240835189819336
# Selected predictors: ['편의점', 'CCTV설치목적_재난재해', '창고시설', '노유자시설', 'CCTV설치목적_쓰레기단속', '제2종근린생활시설', '유치원', '놀이제공영업소', 'const']  AIC: <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f4496f12cf8>
# Processed  38 models on 10 predictors in 0.0592501163482666
# Selected predictors: ['편의점', 'CCTV설치목적_재난재해', '창고시설', '노유자시설', 'CCTV설치목적_쓰레기단속', '제2종근린생활시설', '유치원', '놀이제공영업소', '학교', '식품접객업소', 'const'] AIC:  <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f4496f09e48>
# forward
# Processed  10 models on 9 predictors in 0.022579193115234375
# Selected predictors: ['편의점', 'CCTV설치목적_재난재해', '창고시설', '노유자시설', 'CCTV설치목적_쓰레기단속', '제2종근린생활시설', '유치원', '놀이제공영업소', '학교', 'const']  AIC: <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f4496f03908>
# Processed  37 models on 11 predictors in 0.05952286720275879
# Selected predictors: ['편의점', 'CCTV설치목적_재난재해', '창고시설', '노유자시설', 'CCTV설치목적_쓰레기단속', '제2종근린생활시설', '유치원', '놀이제공영업소', '학교', '식품접객업소', '유흥업소', 'const'] AIC:  <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f4496f12be0>
# forward
# Processed  11 models on 10 predictors in 0.029227733612060547
# Selected predictors: ['편의점', 'CCTV설치목적_재난재해', '창고시설', '노유자시설', 'CCTV설치목적_쓰레기단속', '제2종근린생활시설', '유치원', '놀이제공영업소', '학교', '식품접객업소', 'const']  AIC: <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f4496f12828>
# Processed  36 models on 12 predictors in 0.055924177169799805
# Selected predictors: ['편의점', 'CCTV설치목적_재난재해', '창고시설', '노유자시설', 'CCTV설치목적_쓰레기단속', '제2종근린생활시설', '유치원', '놀이제공영업소', '학교', '식품접객업소', '유흥업소', '주택단지', 'const'] AIC:  <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f4496f0d0f0>
# forward
# Processed  12 models on 11 predictors in 0.027764081954956055
# Selected predictors: ['편의점', 'CCTV설치목적_재난재해', '창고시설', '노유자시설', 'CCTV설치목적_쓰레기단속', '제2종근린생활시설', '유치원', '놀이제공영업소', '식품접객업소', '유흥업소', '주택단지', 'const']  AIC: <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f4496f03320>
# Processed  35 models on 13 predictors in 0.05658149719238281
# Selected predictors: ['편의점', 'CCTV설치목적_재난재해', '창고시설', '노유자시설', 'CCTV설치목적_쓰레기단속', '제2종근린생활시설', '유치원', '놀이제공영업소', '학교', '식품접객업소', '유흥업소', '주택단지', 'CCTV설치목적_생활방범', 'const'] AIC:  <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f4496f03278>
# forward
# Processed  13 models on 12 predictors in 0.03349733352661133
# Selected predictors: ['편의점', 'CCTV설치목적_재난재해', '창고시설', '노유자시설', 'CCTV설치목적_쓰레기단속', '제2종근린생활시설', '유치원', '놀이제공영업소', '식품접객업소', '유흥업소', '주택단지', 'CCTV설치목적_생활방범', 'const']  AIC: <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f447c0a83c8>
# backward
# Processed  35 models on 13 predictors in 0.05614113807678223
# Selected predictors: ['편의점', 'CCTV설치목적_재난재해', '창고시설', '노유자시설', 'CCTV설치목적_쓰레기단속', '제2종근린생활시설', '유치원', '놀이제공영업소', '식품접객업소', '유흥업소', '주택단지', 'CCTV설치목적_생활방범', '아동복지시설', 'const'] AIC:  <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f4496f092e8>
# forward
# Processed  13 models on 12 predictors in 0.0224761962890625
# Selected predictors: ['편의점', 'CCTV설치목적_재난재해', '창고시설', '노유자시설', 'CCTV설치목적_쓰레기단속', '제2종근린생활시설', '유치원', '놀이제공영업소', '식품접객업소', '유흥업소', '주택단지', 'CCTV설치목적_생활방범', 'const']  AIC: <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f4496f03278>
# Processed  34 models on 14 predictors in 0.0645289421081543
# Selected predictors: ['편의점', 'CCTV설치목적_재난재해', '창고시설', '노유자시설', 'CCTV설치목적_쓰레기단속', '제2종근린생활시설', '유치원', '놀이제공영업소', '식품접객업소', '유흥업소', '주택단지', 'CCTV설치목적_생활방범', '아동복지시설', '지구대인원', 'const'] AIC:  <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f4496f0d400>
# forward
# Processed  14 models on 13 predictors in 0.02398538589477539
# Selected predictors: ['편의점', 'CCTV설치목적_재난재해', '창고시설', '노유자시설', 'CCTV설치목적_쓰레기단속', '제2종근린생활시설', '유치원', '놀이제공영업소', '식품접객업소', '유흥업소', '주택단지', 'CCTV설치목적_생활방범', '아동복지시설', 'const']  AIC: <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f4496f12898>
# Processed  33 models on 15 predictors in 0.11850738525390625
# Selected predictors: ['편의점', 'CCTV설치목적_재난재해', '창고시설', '노유자시설', 'CCTV설치목적_쓰레기단속', '제2종근린생활시설', '유치원', '놀이제공영업소', '식품접객업소', '유흥업소', '주택단지', 'CCTV설치목적_생활방범', '아동복지시설', '지구대인원', '문화공원', 'const'] AIC:  <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f4496f09908>
# forward
# Processed  15 models on 14 predictors in 0.025549650192260742
# Selected predictors: ['편의점', 'CCTV설치목적_재난재해', '창고시설', '노유자시설', 'CCTV설치목적_쓰레기단속', '제2종근린생활시설', '유치원', '놀이제공영업소', '식품접객업소', '유흥업소', '주택단지', '아동복지시설', '지구대인원', '문화공원', 'const']  AIC: <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f4496f03c18>
# Processed  32 models on 16 predictors in 0.18752169609069824
# Selected predictors: ['편의점', 'CCTV설치목적_재난재해', '창고시설', '노유자시설', 'CCTV설치목적_쓰레기단속', '제2종근린생활시설', '유치원', '놀이제공영업소', '식품접객업소', '유흥업소', '주택단지', 'CCTV설치목적_생활방범', '아동복지시설', '지구대인원', '문화공원', '교육연구시설', 'const'] AIC:  <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f4496f03dd8>
# forward
# Processed  16 models on 15 predictors in 0.09597897529602051
# Selected predictors: ['편의점', 'CCTV설치목적_재난재해', '창고시설', '노유자시설', 'CCTV설치목적_쓰레기단속', '제2종근린생활시설', '유치원', '놀이제공영업소', '식품접객업소', '유흥업소', '주택단지', '아동복지시설', '지구대인원', '문화공원', '교육연구시설', 'const']  AIC: <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f447c0a87f0>
# backward
# Processed  32 models on 16 predictors in 0.12580132484436035
# Selected predictors: ['편의점', 'CCTV설치목적_재난재해', '창고시설', '노유자시설', 'CCTV설치목적_쓰레기단속', '제2종근린생활시설', '유치원', '놀이제공영업소', '식품접객업소', '유흥업소', '주택단지', '아동복지시설', '지구대인원', '문화공원', '교육연구시설', '소공원', 'const'] AIC:  <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f4496f03710>
# forward
# Processed  16 models on 15 predictors in 0.027225971221923828
# Selected predictors: ['편의점', 'CCTV설치목적_재난재해', '창고시설', '노유자시설', 'CCTV설치목적_쓰레기단속', '제2종근린생활시설', '유치원', '놀이제공영업소', '식품접객업소', '유흥업소', '주택단지', '아동복지시설', '지구대인원', '문화공원', '교육연구시설', 'const']  AIC: <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f4496f09550>
# Processed  31 models on 17 predictors in 0.12377452850341797
# Selected predictors: ['편의점', 'CCTV설치목적_재난재해', '창고시설', '노유자시설', 'CCTV설치목적_쓰레기단속', '제2종근린생활시설', '유치원', '놀이제공영업소', '식품접객업소', '유흥업소', '주택단지', '아동복지시설', '지구대인원', '문화공원', '교육연구시설', '소공원', '공장', 'const'] AIC:  <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f4496f09358>
# forward
# Processed  17 models on 16 predictors in 0.10056686401367188
# Selected predictors: ['편의점', '창고시설', '노유자시설', 'CCTV설치목적_쓰레기단속', '제2종근린생활시설', '유치원', '놀이제공영업소', '식품접객업소', '유흥업소', '주택단지', '아동복지시설', '지구대인원', '문화공원', '교육연구시설', '소공원', '공장', 'const']  AIC: <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f4496f09630>
# Processed  30 models on 18 predictors in 0.1236276626586914
# Selected predictors: ['편의점', 'CCTV설치목적_재난재해', '창고시설', '노유자시설', 'CCTV설치목적_쓰레기단속', '제2종근린생활시설', '유치원', '놀이제공영업소', '식품접객업소', '유흥업소', '주택단지', '아동복지시설', '지구대인원', '문화공원', '교육연구시설', '소공원', '공장', '건설이후(일)', 'const'] AIC:  <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f4496f12160>
# forward
# Processed  18 models on 17 predictors in 0.10308480262756348
# Selected predictors: ['편의점', 'CCTV설치목적_재난재해', '창고시설', '노유자시설', 'CCTV설치목적_쓰레기단속', '제2종근린생활시설', '유치원', '식품접객업소', '유흥업소', '주택단지', '아동복지시설', '지구대인원', '문화공원', '교육연구시설', '소공원', '공장', '건설이후(일)', 'const']  AIC: <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f4496efab70>
# backward
# Processed  30 models on 18 predictors in 0.1964411735534668
# Selected predictors: ['편의점', 'CCTV설치목적_재난재해', '창고시설', '노유자시설', 'CCTV설치목적_쓰레기단속', '제2종근린생활시설', '유치원', '식품접객업소', '유흥업소', '주택단지', '아동복지시설', '지구대인원', '문화공원', '교육연구시설', '소공원', '공장', '건설이후(일)', '근린공원', 'const'] AIC:  <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f4496f096d8>
# forward
# Processed  18 models on 17 predictors in 0.10278129577636719
# Selected predictors: ['편의점', '창고시설', '노유자시설', 'CCTV설치목적_쓰레기단속', '제2종근린생활시설', '유치원', '식품접객업소', '유흥업소', '주택단지', '아동복지시설', '지구대인원', '문화공원', '교육연구시설', '소공원', '공장', '건설이후(일)', '근린공원', 'const']  AIC: <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f4496f09128>
# Processed  29 models on 19 predictors in 0.19248557090759277
# Selected predictors: ['편의점', 'CCTV설치목적_재난재해', '창고시설', '노유자시설', 'CCTV설치목적_쓰레기단속', '제2종근린생활시설', '유치원', '식품접객업소', '유흥업소', '주택단지', '아동복지시설', '지구대인원', '문화공원', '교육연구시설', '소공원', '공장', '건설이후(일)', '근린공원', '제1종근린생활시설', 'const'] AIC:  <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f4496f0da90>
# forward
# Processed  19 models on 18 predictors in 0.10648846626281738
# Selected predictors: ['편의점', '창고시설', '노유자시설', 'CCTV설치목적_쓰레기단속', '제2종근린생활시설', '유치원', '식품접객업소', '유흥업소', '주택단지', '아동복지시설', '지구대인원', '문화공원', '교육연구시설', '소공원', '공장', '건설이후(일)', '근린공원', '제1종근린생활시설', 'const']  AIC: <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f4496f039e8>
# Processed  28 models on 20 predictors in 0.2007293701171875
# Selected predictors: ['편의점', 'CCTV설치목적_재난재해', '창고시설', '노유자시설', 'CCTV설치목적_쓰레기단속', '제2종근린생활시설', '유치원', '식품접객업소', '유흥업소', '주택단지', '아동복지시설', '지구대인원', '문화공원', '교육연구시설', '소공원', '공장', '건설이후(일)', '근린공원', '제1종근린생활시설', '역사공원', 'const'] AIC:  <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f4496f0d898>
# forward
# Processed  20 models on 19 predictors in 0.10741949081420898
# Selected predictors: ['편의점', '창고시설', '노유자시설', 'CCTV설치목적_쓰레기단속', '제2종근린생활시설', '유치원', '식품접객업소', '유흥업소', '주택단지', '아동복지시설', '지구대인원', '문화공원', '교육연구시설', '소공원', '공장', '건설이후(일)', '근린공원', '제1종근린생활시설', '역사공원', 'const']  AIC: <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f4496f12128>
# Processed  27 models on 21 predictors in 0.198042631149292
# Selected predictors: ['편의점', 'CCTV설치목적_재난재해', '창고시설', '노유자시설', 'CCTV설치목적_쓰레기단속', '제2종근린생활시설', '유치원', '식품접객업소', '유흥업소', '주택단지', '아동복지시설', '지구대인원', '문화공원', '교육연구시설', '소공원', '공장', '건설이후(일)', '근린공원', '제1종근린생활시설', '역사공원', '어린이놀이시설', 'const'] AIC:  <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f4496f12780>
# forward
# Processed  21 models on 20 predictors in 0.17963075637817383
# Selected predictors: ['편의점', 'CCTV설치목적_재난재해', '창고시설', '노유자시설', 'CCTV설치목적_쓰레기단속', '제2종근린생활시설', '유치원', '식품접객업소', '유흥업소', '아동복지시설', '지구대인원', '문화공원', '교육연구시설', '소공원', '공장', '건설이후(일)', '근린공원', '제1종근린생활시설', '역사공원', '어린이놀이시설', 'const']  AIC: <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f4496f03320>
# backward
# Processed  27 models on 21 predictors in 0.12157773971557617
# Selected predictors: ['편의점', 'CCTV설치목적_재난재해', '창고시설', '노유자시설', 'CCTV설치목적_쓰레기단속', '제2종근린생활시설', '유치원', '식품접객업소', '유흥업소', '아동복지시설', '지구대인원', '문화공원', '교육연구시설', '소공원', '공장', '건설이후(일)', '근린공원', '제1종근린생활시설', '역사공원', '어린이놀이시설', 'CCTV설치목적_어린이보호', 'const'] AIC:  <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f4496efa748>
# forward
# Processed  21 models on 20 predictors in 0.10740995407104492
# Selected predictors: ['편의점', 'CCTV설치목적_재난재해', '창고시설', '노유자시설', 'CCTV설치목적_쓰레기단속', '유치원', '식품접객업소', '유흥업소', '아동복지시설', '지구대인원', '문화공원', '교육연구시설', '소공원', '공장', '건설이후(일)', '근린공원', '제1종근린생활시설', '역사공원', '어린이놀이시설', 'CCTV설치목적_어린이보호', 'const']  AIC: <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f4496f03080>
# backward
# Processed  27 models on 21 predictors in 0.19089221954345703
# Selected predictors: ['편의점', 'CCTV설치목적_재난재해', '창고시설', '노유자시설', 'CCTV설치목적_쓰레기단속', '유치원', '식품접객업소', '유흥업소', '아동복지시설', '지구대인원', '문화공원', '교육연구시설', '소공원', '공장', '건설이후(일)', '근린공원', '제1종근린생활시설', '역사공원', '어린이놀이시설', 'CCTV설치목적_어린이보호', '안전비상벨_공원', 'const'] AIC:  <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f4496f0d710>
# forward
# Processed  21 models on 20 predictors in 0.10865902900695801
# Selected predictors: ['편의점', 'CCTV설치목적_재난재해', '창고시설', '노유자시설', 'CCTV설치목적_쓰레기단속', '유치원', '식품접객업소', '유흥업소', '아동복지시설', '지구대인원', '문화공원', '교육연구시설', '소공원', '공장', '건설이후(일)', '근린공원', '제1종근린생활시설', '역사공원', '어린이놀이시설', 'CCTV설치목적_어린이보호', 'const']  AIC: <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f447c0a8240>
# Processed  26 models on 22 predictors in 0.18750214576721191
# Selected predictors: ['편의점', 'CCTV설치목적_재난재해', '창고시설', '노유자시설', 'CCTV설치목적_쓰레기단속', '유치원', '식품접객업소', '유흥업소', '아동복지시설', '지구대인원', '문화공원', '교육연구시설', '소공원', '공장', '건설이후(일)', '근린공원', '제1종근린생활시설', '역사공원', '어린이놀이시설', 'CCTV설치목적_어린이보호', '안전비상벨_공원', 'CCTV설치목적_교통단속', 'const'] AIC:  <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f4496f09c50>
# forward
# Processed  22 models on 21 predictors in 0.11071634292602539
# Selected predictors: ['편의점', '창고시설', '노유자시설', 'CCTV설치목적_쓰레기단속', '유치원', '식품접객업소', '유흥업소', '아동복지시설', '지구대인원', '문화공원', '교육연구시설', '소공원', '공장', '건설이후(일)', '근린공원', '제1종근린생활시설', '역사공원', '어린이놀이시설', 'CCTV설치목적_어린이보호', '안전비상벨_공원', 'CCTV설치목적_교통단속', 'const']  AIC: <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f4496f12a90>
# Processed  25 models on 23 predictors in 0.1887645721435547
# Selected predictors: ['편의점', 'CCTV설치목적_재난재해', '창고시설', '노유자시설', 'CCTV설치목적_쓰레기단속', '유치원', '식품접객업소', '유흥업소', '아동복지시설', '지구대인원', '문화공원', '교육연구시설', '소공원', '공장', '건설이후(일)', '근린공원', '제1종근린생활시설', '역사공원', '어린이놀이시설', 'CCTV설치목적_어린이보호', '안전비상벨_공원', 'CCTV설치목적_교통단속', '안전비상벨_화장실', 'const'] AIC:  <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f447c0a8a90>
# forward
# Processed  23 models on 22 predictors in 0.18053364753723145
# Selected predictors: ['편의점', 'CCTV설치목적_재난재해', '창고시설', '노유자시설', 'CCTV설치목적_쓰레기단속', '유치원', '식품접객업소', '유흥업소', '아동복지시설', '지구대인원', '문화공원', '교육연구시설', '소공원', '공장', '건설이후(일)', '근린공원', '제1종근린생활시설', '역사공원', '어린이놀이시설', 'CCTV설치목적_어린이보호', '안전비상벨_공원', 'CCTV설치목적_교통단속', 'const']  AIC: <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f4496f092b0>
# Processed  24 models on 24 predictors in 0.2015984058380127
# Selected predictors: ['편의점', 'CCTV설치목적_재난재해', '창고시설', '노유자시설', 'CCTV설치목적_쓰레기단속', '유치원', '식품접객업소', '유흥업소', '아동복지시설', '지구대인원', '문화공원', '교육연구시설', '소공원', '공장', '건설이후(일)', '근린공원', '제1종근린생활시설', '역사공원', '어린이놀이시설', 'CCTV설치목적_어린이보호', '안전비상벨_공원', 'CCTV설치목적_교통단속', '안전비상벨_화장실', '안전비상벨', 'const'] AIC:  <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f4496efac88>
# forward
# Processed  24 models on 23 predictors in 0.2067403793334961
# Selected predictors: ['편의점', 'CCTV설치목적_재난재해', '창고시설', '노유자시설', '유치원', '식품접객업소', '유흥업소', '아동복지시설', '지구대인원', '문화공원', '교육연구시설', '소공원', '공장', '건설이후(일)', '근린공원', '제1종근린생활시설', '역사공원', '어린이놀이시설', 'CCTV설치목적_어린이보호', '안전비상벨_공원', 'CCTV설치목적_교통단속', '안전비상벨_화장실', '안전비상벨', 'const']  AIC: <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f4496f124a8>
# backward
# Processed  24 models on 24 predictors in 0.20133566856384277
# Selected predictors: ['편의점', 'CCTV설치목적_재난재해', '창고시설', '노유자시설', '유치원', '식품접객업소', '유흥업소', '아동복지시설', '지구대인원', '문화공원', '교육연구시설', '소공원', '공장', '건설이후(일)', '근린공원', '제1종근린생활시설', '역사공원', '어린이놀이시설', 'CCTV설치목적_어린이보호', '안전비상벨_공원', 'CCTV설치목적_교통단속', '안전비상벨_화장실', '안전비상벨', '종교시설', 'const'] AIC:  <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f4496f09630>
# forward
# Processed  24 models on 23 predictors in 0.2033376693725586
# Selected predictors: ['편의점', 'CCTV설치목적_재난재해', '창고시설', '노유자시설', '유치원', '식품접객업소', '유흥업소', '아동복지시설', '지구대인원', '문화공원', '교육연구시설', '소공원', '공장', '건설이후(일)', '근린공원', '제1종근린생활시설', '역사공원', '어린이놀이시설', 'CCTV설치목적_어린이보호', '안전비상벨_공원', 'CCTV설치목적_교통단속', '안전비상벨_화장실', '안전비상벨', 'const']  AIC: <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f4496f09128>
# Processed  23 models on 25 predictors in 0.11581158638000488
# Selected predictors: ['편의점', 'CCTV설치목적_재난재해', '창고시설', '노유자시설', '유치원', '식품접객업소', '유흥업소', '아동복지시설', '지구대인원', '문화공원', '교육연구시설', '소공원', '공장', '건설이후(일)', '근린공원', '제1종근린생활시설', '역사공원', '어린이놀이시설', 'CCTV설치목적_어린이보호', '안전비상벨_공원', 'CCTV설치목적_교통단속', '안전비상벨_화장실', '안전비상벨', '종교시설', '건물연한', 'const'] AIC:  <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f4496f0dd30>
# forward
# Processed  25 models on 24 predictors in 0.2986490726470947
# Selected predictors: ['편의점', 'CCTV설치목적_재난재해', '창고시설', '노유자시설', '유치원', '식품접객업소', '유흥업소', '아동복지시설', '지구대인원', '문화공원', '교육연구시설', '소공원', '공장', '건설이후(일)', '근린공원', '제1종근린생활시설', '어린이놀이시설', 'CCTV설치목적_어린이보호', '안전비상벨_공원', 'CCTV설치목적_교통단속', '안전비상벨_화장실', '안전비상벨', '종교시설', '건물연한', 'const']  AIC: <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f4496efa470>
# backward
# Processed  23 models on 25 predictors in 0.20207881927490234
# Selected predictors: ['편의점', 'CCTV설치목적_재난재해', '창고시설', '노유자시설', '유치원', '식품접객업소', '유흥업소', '아동복지시설', '지구대인원', '문화공원', '교육연구시설', '소공원', '공장', '건설이후(일)', '근린공원', '제1종근린생활시설', '어린이놀이시설', 'CCTV설치목적_어린이보호', '안전비상벨_공원', 'CCTV설치목적_교통단속', '안전비상벨_화장실', '안전비상벨', '종교시설', '건물연한', '건물노후도', 'const'] AIC:  <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f4496f0d5f8>
# forward
# Processed  25 models on 24 predictors in 0.20355963706970215
# Selected predictors: ['편의점', 'CCTV설치목적_재난재해', '창고시설', '노유자시설', '유치원', '식품접객업소', '유흥업소', '아동복지시설', '지구대인원', '문화공원', '교육연구시설', '소공원', '공장', '건설이후(일)', '근린공원', '제1종근린생활시설', '어린이놀이시설', 'CCTV설치목적_어린이보호', '안전비상벨_공원', 'CCTV설치목적_교통단속', '안전비상벨_화장실', '안전비상벨', '종교시설', '건물연한', 'const']  AIC: <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f4496f037b8>
# Processed  22 models on 26 predictors in 0.12322783470153809
# Selected predictors: ['편의점', 'CCTV설치목적_재난재해', '창고시설', '노유자시설', '유치원', '식품접객업소', '유흥업소', '아동복지시설', '지구대인원', '문화공원', '교육연구시설', '소공원', '공장', '건설이후(일)', '근린공원', '제1종근린생활시설', '어린이놀이시설', 'CCTV설치목적_어린이보호', '안전비상벨_공원', 'CCTV설치목적_교통단속', '안전비상벨_화장실', '안전비상벨', '종교시설', '건물연한', '건물노후도', '업무시설', 'const'] AIC:  <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f4496f039e8>
# forward
# Processed  26 models on 25 predictors in 0.11751556396484375
# Selected predictors: ['편의점', 'CCTV설치목적_재난재해', '창고시설', '노유자시설', '유치원', '식품접객업소', '유흥업소', '아동복지시설', '지구대인원', '문화공원', '교육연구시설', '소공원', '공장', '건설이후(일)', '근린공원', '제1종근린생활시설', '어린이놀이시설', 'CCTV설치목적_어린이보호', '안전비상벨_공원', 'CCTV설치목적_교통단속', '안전비상벨_화장실', '안전비상벨', '종교시설', '건물연한', '건물노후도', 'const']  AIC: <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f4496f03f98>
# Processed  21 models on 27 predictors in 0.17991304397583008
# Selected predictors: ['편의점', 'CCTV설치목적_재난재해', '창고시설', '노유자시설', '유치원', '식품접객업소', '유흥업소', '아동복지시설', '지구대인원', '문화공원', '교육연구시설', '소공원', '공장', '건설이후(일)', '근린공원', '제1종근린생활시설', '어린이놀이시설', 'CCTV설치목적_어린이보호', '안전비상벨_공원', 'CCTV설치목적_교통단속', '안전비상벨_화장실', '안전비상벨', '종교시설', '건물연한', '건물노후도', '업무시설', '단독주택', 'const'] AIC:  <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f4496f0deb8>
# forward
# Processed  27 models on 26 predictors in 0.11752653121948242
# Selected predictors: ['편의점', 'CCTV설치목적_재난재해', '창고시설', '노유자시설', '유치원', '식품접객업소', '유흥업소', '아동복지시설', '지구대인원', '문화공원', '교육연구시설', '소공원', '공장', '건설이후(일)', '근린공원', '제1종근린생활시설', '어린이놀이시설', 'CCTV설치목적_어린이보호', '안전비상벨_공원', 'CCTV설치목적_교통단속', '안전비상벨_화장실', '안전비상벨', '종교시설', '건물연한', '건물노후도', '업무시설', 'const']  AIC: <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f4496f03eb8>
# Processed  20 models on 28 predictors in 0.1754446029663086
# Selected predictors: ['편의점', 'CCTV설치목적_재난재해', '창고시설', '노유자시설', '유치원', '식품접객업소', '유흥업소', '아동복지시설', '지구대인원', '문화공원', '교육연구시설', '소공원', '공장', '건설이후(일)', '근린공원', '제1종근린생활시설', '어린이놀이시설', 'CCTV설치목적_어린이보호', '안전비상벨_공원', 'CCTV설치목적_교통단속', '안전비상벨_화장실', '안전비상벨', '종교시설', '건물연한', '건물노후도', '업무시설', '단독주택', '학교', 'const'] AIC:  <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f4496efacc0>
# forward
# Processed  28 models on 27 predictors in 0.19236207008361816
# Selected predictors: ['편의점', '창고시설', '노유자시설', '유치원', '식품접객업소', '유흥업소', '아동복지시설', '지구대인원', '문화공원', '교육연구시설', '소공원', '공장', '건설이후(일)', '근린공원', '제1종근린생활시설', '어린이놀이시설', 'CCTV설치목적_어린이보호', '안전비상벨_공원', 'CCTV설치목적_교통단속', '안전비상벨_화장실', '안전비상벨', '종교시설', '건물연한', '건물노후도', '업무시설', '단독주택', '학교', 'const']  AIC: <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7
 'const'] AIC:  <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f4496f12e80>
# forward
# Processed  32 models on 31 predictors in 0.3049170970916748
# Selected predictors: ['편의점', 'CCTV설치목적_재난재해', '창고시설', '노유자시설', '유치원', '식품접객업소', '유흥업소', '아동복지시설', '지구대인원', '문화공원', '교육연구시설', '소공원', '공장', '건설이후(일)', '제1종근린생활시설', '어린이놀이시설', 'CCTV설치목적_어린이보호', '안전비상벨_공원', '안전비상벨_화장실', '안전비상벨', '종교시설', '건물연한', '건물노후도', '업무시설', '학교', '안전비상벨_가로변', '생활관련시설', '주택단지', '경찰관서', '체육공원', 'CCTV설치대수', 'const']  AIC: <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f445f253198>
# backward
# Processed  16 models on 32 predictors in 0.19558286666870117
# Selected predictors: ['편의점', 'CCTV설치목적_재난재해', '창고시설', '노유자시설', '유치원', '식품접객업소', '유흥업소', '아동복지시설', '지구대인원', '문화공원', '교육연구시설', '소공원', '공장', '건설이후(일)', '제1종근린생활시설', '어린이놀이시설', 'CCTV설치목적_어린이보호', '안전비상벨_공원', '안전비상벨_화장실', '안전비상벨', '종교시설', '건물연한', '건물노후도', '업무시설', '학교', '안전비상벨_가로변', '생활관련시설', '주택단지', '경찰관서', '체육공원', 'CCTV설치대수', '전체공원', 'const'] AIC:  <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f445f253208>
# forward
# Processed  32 models on 31 predictors in 0.29710841178894043
# Selected predictors: ['편의점', 'CCTV설치목적_재난재해', '창고시설', '노유자시설', '유치원', '식품접객업소', '유흥업소', '아동복지시설', '지구대인원', '문화공원', '교육연구시설', '소공원', '공장', '건설이후(일)', '제1종근린생활시설', '어린이놀이시설', 'CCTV설치목적_어린이보호', '안전비상벨_공원', '안전비상벨_화장실', '안전비상벨', '종교시설', '건물연한', '건물노후도', '업무시설', '학교', '안전비상벨_가로변', '생활관련시설', '주택단지', '경찰관서', 'CCTV설치대수', '전체공원', 'const']  AIC: <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f4496f0db70>
# Processed  15 models on 33 predictors in 0.18147993087768555
# Selected predictors: ['편의점', 'CCTV설치목적_재난재해', '창고시설', '노유자시설', '유치원', '식품접객업소', '유흥업소', '아동복지시설', '지구대인원', '문화공원', '교육연구시설', '소공원', '공장', '건설이후(일)', '제1종근린생활시설', '어린이놀이시설', 'CCTV설치목적_어린이보호', '안전비상벨_공원', '안전비상벨_화장실', '안전비상벨', '종교시설', '건물연한', '건물노후도', '업무시설', '학교', '안전비상벨_가로변', '생활관련시설', '주택단지', '경찰관서', '체육공원', 'CCTV설치대수', '전체공원', '대규모점포', 'const'] AIC:  <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f445f253e80>
# forward
# Processed  33 models on 32 predictors in 0.3069906234741211
# Selected predictors: ['편의점', 'CCTV설치목적_재난재해', '창고시설', '노유자시설', '유치원', '식품접객업소', '유흥업소', '아동복지시설', '지구대인원', '문화공원', '교육연구시설', '소공원', '공장', '건설이후(일)', '제1종근린생활시설', '어린이놀이시설', 'CCTV설치목적_어린이보호', '안전비상벨_공원', '안전비상벨_화장실', '안전비상벨', '종교시설', '건물연한', '건물노후도', '업무시설', '학교', '안전비상벨_가로변', '생활관련시설', '주택단지', '경찰관서', '체육공원', 'CCTV설치대수', '전체공원', 'const']  AIC: <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f4496f12e80>
# Total elapsed time: 12.453891038894653 seconds.

# %%
step_best_model_ctc.summary()
## P>|t|가 0.05보다 크면 별로인 것
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   신고건수   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                     9082.
# Date:                Sat, 09 Oct 2021   Prob (F-statistic):           7.14e-12
# Time:                        19:47:52   Log-Likelihood:                -245.10
# No. Observations:                  40   AIC:                             558.2
# Df Residuals:                       6   BIC:                             615.6
# Df Model:                          33
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# 편의점             5.313e+04   1567.359     33.900      0.000    4.93e+04     5.7e+04
# CCTV설치목적_재난재해   1.454e+04    963.077     15.100      0.000    1.22e+04    1.69e+04
# 창고시설           -7.808e+04   1710.001    -45.662      0.000   -8.23e+04   -7.39e+04
# 노유자시설           6.068e+04   2219.035     27.347      0.000    5.53e+04    6.61e+04
# 유치원            -8.149e+04   2130.031    -38.258      0.000   -8.67e+04   -7.63e+04
# 식품접객업소         -5.671e+04   1005.466    -56.398      0.000   -5.92e+04   -5.42e+04
# 유흥업소            8.741e+04   1854.531     47.133      0.000    8.29e+04    9.19e+04
# 아동복지시설         -3.037e+04   1219.068    -24.915      0.000   -3.34e+04   -2.74e+04
# 지구대인원           1.207e+04    336.623     35.854      0.000    1.12e+04    1.29e+04
# 문화공원            4.692e+04   1133.972     41.376      0.000    4.41e+04    4.97e+04
# 교육연구시설          6451.0815   1847.325      3.492      0.013    1930.839     1.1e+04
# 소공원             3.868e+04   1029.597     37.572      0.000    3.62e+04    4.12e+04
# 공장             -3.745e+04    936.594    -39.983      0.000   -3.97e+04   -3.52e+04
# 건설이후(일)        -8.381e+04   4764.812    -17.589      0.000   -9.55e+04   -7.21e+04
# 제1종근린생활시설       5.703e+04   1331.948     42.819      0.000    5.38e+04    6.03e+04
# 어린이놀이시설         3.227e+05   1.56e+04     20.737      0.000    2.85e+05    3.61e+05
# CCTV설치목적_어린이보호 -1.438e+04    469.779    -30.620      0.000   -1.55e+04   -1.32e+04
# 안전비상벨_공원        2.789e+04    748.278     37.275      0.000    2.61e+04    2.97e+04
# 안전비상벨_화장실       1.423e+04    451.522     31.506      0.000    1.31e+04    1.53e+04
# 안전비상벨          -2.418e+04    864.773    -27.959      0.000   -2.63e+04   -2.21e+04
# 종교시설           -9055.1155    677.437    -13.367      0.000   -1.07e+04   -7397.488
# 건물연한           -6.521e+04   2380.479    -27.395      0.000    -7.1e+04   -5.94e+04
# 건물노후도           2.602e+04   1217.021     21.384      0.000     2.3e+04     2.9e+04
# 업무시설           -2.255e+04   1062.740    -21.220      0.000   -2.52e+04      -2e+04
# 학교             -7.388e+04   2160.122    -34.202      0.000   -7.92e+04   -6.86e+04
# 안전비상벨_가로변       2.156e+04    909.226     23.713      0.000    1.93e+04    2.38e+04
# 생활관련시설         -7.276e+04   2995.700    -24.290      0.000   -8.01e+04   -6.54e+04
# 주택단지             -1.2e+05   7939.592    -15.109      0.000   -1.39e+05   -1.01e+05
# 경찰관서           -1.134e+04    908.820    -12.482      0.000   -1.36e+04   -9120.413
# 체육공원            2137.5138    680.146      3.143      0.020     473.256    3801.771
# CCTV설치대수       -2.159e+04   2197.747     -9.823      0.000    -2.7e+04   -1.62e+04
# 전체공원           -2.879e+04   3603.128     -7.990      0.000   -3.76e+04      -2e+04
# 대규모점포           2100.8963    705.007      2.980      0.025     375.805    3825.987
# const           4.044e+04   1223.465     33.051      0.000    3.74e+04    4.34e+04
# ==============================================================================
# Omnibus:                        0.307   Durbin-Watson:                   2.394
# Prob(Omnibus):                  0.858   Jarque-Bera (JB):                0.154
# Skew:                          -0.148   Prob(JB):                        0.926
# Kurtosis:                       2.928   Cond. No.                         875.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
#OLS모형을 적합하는 과정을 함수로 정의

def ols(data_x, data_y, w_matrix):
    x = np.array(data_x)
    y = np.array(data_y)
    
    name_x = list(data_x.columns)
    name_y = list(data_y.columns)
    
    ols = OLS(y = y, x = x, w = w_matrix, name_x = name_x, name_y = name_y, white_test = True, spat_diag = True, moran = True)
    
    print(ols.summary)
    
    return ols

# %%
#SEM_GM모형을 적합하는 과정을 함수로 정의

def gmerror(data_x, data_y, w_matrix):
    x = np.array(data_x)
    y = np.array(data_y)
    
    name_x = list(data_x.columns)
    name_y = list(data_y.columns)
    
    gmerror = GM_Error(y = y, x = x, w = w_matrix, name_x = name_x, name_y = name_y)
    
    print(gmerror.summary)
    
    return gmerror

# %%
#SEM_ML모형을 적합하는 과정을 함수로 정의

def mlerror(data_x, data_y, w_matrix):
    x = np.array(data_x)
    y = np.array(data_y)
    
    name_x = list(data_x.columns)
    name_y = list(data_y.columns)
    
    mlerror = ML_Error(y = y, x = x, w = w_matrix, name_x = name_x, name_y = name_y)
    stat_Q_risk, p_Q_risk = shapiro(mlerror.e_filtered)
    
    print(stat_Q_risk, p_Q_risk)
    print(mlerror.summary)
    
    return mlerror

# %%
#SLM_GM모형을 적합하는 과정을 함수로 정의

def gmlag(data_x, data_y, w_matrix):
    x = np.array(data_x)
    y = np.array(data_y)
    
    name_x = list(data_x.columns)
    name_y = list(data_y.columns)
    
    gmlag = GM_Lag(y = y, x = x, w = w_matrix, name_x = name_x)
    
    print(gmlag.summary)
    
    return gmlag

# %%
#SLM_ML모형을 적합하는 과정을 함수로 정의

def mllag(data_x, data_y, w_matrix):
    x = np.array(data_x)
    y = np.array(data_y)
    
    name_x = list(data_x.columns)
    name_y = list(data_y.columns)
    
    mllag = ML_Lag(y = y, x = x, w = w_matrix, name_x = name_x)
    
    print(mllag.summary)
    
    return mllag

# %%
# 정규성 검정
shapiro(y)
# Out:
# ShapiroResult(statistic=0.9645305871963501, pvalue=0.23850251734256744)

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
from libpysal.weights.contiguity import Queen
from libpysal import examples
import numpy as np
import pandas as pd
import geopandas as gpd
import os
import splot

# %%
gdf = gpd.read_file('11.4개시도_경찰서_관할경계.geojson')
gdf
# Out:
#         NAME  PNAME                                           geometry
# 0      진주경찰서    경남청  MULTIPOLYGON (((128.26697 35.12927, 128.26697 ...
# 1    창원서부경찰서    경남청  MULTIPOLYGON (((128.63363 35.22152, 128.63357 ...
# 2    창원중부경찰서    경남청  MULTIPOLYGON (((128.60966 35.15093, 128.60956 ...
# 3    마산동부경찰서    경남청  MULTIPOLYGON (((128.62696 35.21714, 128.62695 ...
# 4    마산중부경찰서    경남청  MULTIPOLYGON (((128.43007 35.05918, 128.43005 ...
# 5      진해경찰서    경남청  MULTIPOLYGON (((128.81143 35.07759, 128.80804 ...
# 6    서울강동경찰서    서울청  MULTIPOLYGON (((127.11397 37.55685, 127.11397 ...
# 7    서울송파경찰서    서울청  MULTIPOLYGON (((127.14542 37.51605, 127.14519 ...
# 8    서울수서경찰서    서울청  MULTIPOLYGON (((127.12420 37.46652, 127.12414 ...
# 9    서울방배경찰서    서울청  MULTIPOLYGON (((127.00365 37.46771, 127.00305 ...
# 10  서울남대문경찰서    서울청  MULTIPOLYGON (((126.97291 37.56934, 126.97320 ...
# 11   서울서부경찰서    서울청  MULTIPOLYGON (((126.88405 37.59237, 126.88405 ...
# 12   서울양천경찰서    서울청  MULTIPOLYGON (((126.82457 37.50826, 126.82461 ...
# 13   서울강서경찰서    서울청  MULTIPOLYGON (((126.82216 37.54067, 126.82220 ...
# 14   서울성북경찰서    서울청  MULTIPOLYGON (((126.98198 37.63512, 126.98203 ...
# 15   서울용산경찰서    서울청  MULTIPOLYGON (((126.96882 37.55497, 126.96886 ...
# 16   서울광진경찰서    서울청  MULTIPOLYGON (((127.10514 37.55638, 127.10540 ...
# 17   서울종암경찰서    서울청  MULTIPOLYGON (((127.05690 37.61777, 127.05699 ...
# 18   수원남부경찰서  경기남부청  MULTIPOLYGON (((127.03963 37.32102, 127.03969 ...
# 19  서울동대문경찰서    서울청  MULTIPOLYGON (((127.07123 37.60757, 127.07136 ...
# 20   서울성동경찰서    서울청  MULTIPOLYGON (((127.04291 37.57219, 127.04788 ...
# 21   서울중부경찰서    서울청  MULTIPOLYGON (((127.02335 37.57140, 127.02329 ...
# 22   서울혜화경찰서    서울청  MULTIPOLYGON (((126.99897 37.59234, 126.99917 ...
# 23   서울중랑경찰서    서울청  MULTIPOLYGON (((127.10698 37.62052, 127.10698 ...
# 24   서울강남경찰서    서울청  MULTIPOLYGON (((127.06282 37.52247, 127.06284 ...
# 25   서울서초경찰서    서울청  MULTIPOLYGON (((127.05232 37.42857, 127.05221 ...
# 26  서울서대문경찰서    서울청  MULTIPOLYGON (((126.94971 37.60957, 126.95031 ...
# 27   서울종로경찰서    서울청  MULTIPOLYGON (((126.95984 37.62979, 126.95984 ...
# 28   서울마포경찰서    서울청  MULTIPOLYGON (((126.85196 37.57433, 126.85196 ...
# 29   수원서부경찰서  경기남부청  MULTIPOLYGON (((126.99699 37.22926, 126.99698 ...
# 30   수원중부경찰서  경기남부청  MULTIPOLYGON (((127.03177 37.33654, 127.03176 ...
# 31   서울관악경찰서    서울청  MULTIPOLYGON (((126.98834 37.45805, 126.98816 ...
# 32   서울동작경찰서    서울청  MULTIPOLYGON (((126.94512 37.51843, 126.94521 ...
# 33   서울금천경찰서    서울청  MULTIPOLYGON (((126.92842 37.45020, 126.92840 ...
# 34   서울구로경찰서    서울청  MULTIPOLYGON (((126.88064 37.51591, 126.88117 ...
# 35  서울영등포경찰서    서울청  MULTIPOLYGON (((126.87511 37.55453, 126.87596 ...
# 36   서울도봉경찰서    서울청  MULTIPOLYGON (((127.00865 37.68445, 127.00866 ...
# 37   서울은평경찰서    서울청  MULTIPOLYGON (((126.90175 37.60571, 126.90175 ...
# 38   서울강북경찰서    서울청  MULTIPOLYGON (((126.98267 37.63578, 126.98278 ...
# 39   서울노원경찰서    서울청  MULTIPOLYGON (((127.05177 37.68582, 127.05177 ...

# %%
w = Queen.from_dataframe(gdf)
w.transform = 'r'

# %% [markdown]
# ## 여기부턴
# - http://pysal.org/notebooks/viz/splot/esda_morans_viz.html

# %%
from esda.moran import Moran

w = Queen.from_dataframe(gdf)
moran = Moran(y, w)
moran.I
# Out:
# -0.042048409683158094

# %%
from splot.esda import moran_scatterplot

# %%
fig, ax = moran_scatterplot(moran, aspect_equal=True)
plt.show()

# %%
from splot.esda import plot_moran

plot_moran(moran, zstandard=True, figsize=(10,4))
plt.show()

# %%
moran.p_sim
# Out:
# 0.483

# %%
from splot.esda import moran_scatterplot
from esda.moran import Moran_Local

# calculate Moran_Local and plot
moran_loc = Moran_Local(y, w)
fig, ax = moran_scatterplot(moran_loc)
ax.set_xlabel('Donatns')
ax.set_ylabel('Spatial Lag of Donatns')
plt.show()

# %%
fig, ax = moran_scatterplot(moran_loc, p=0.05)
ax.set_xlabel('Donatns')
ax.set_ylabel('Spatial Lag of Donatns')
plt.show()

# %%
from splot.esda import lisa_cluster

lisa_cluster(moran_loc, gdf, p=0.05, figsize = (9,9))
plt.show()

# %% [markdown]
# ## 잠시 대기

# %%
#y_df=pd.DataFrame(df_y['신고건수'])

# %%
#scaled_X.drop(['const'], axis=1, inplace=True)

# %%
scaled_X.shape
# Out:
# (40, 48)

# %%
y.shape
# Out:
# (40, 1)

# %% [markdown]
# ### 웨 안 되는지는 모르겠는데 행보다 열이 많으면 안 된대..
#
# -> 일단 반만 선택 ㄱ

# %%
half_X=scaled_X.iloc[:, :20]

# %%
ols_Q_ctc = ols(half_X, y, w)
# Out:
# REGRESSION
# ----------
# SUMMARY OF OUTPUT: ORDINARY LEAST SQUARES
# -----------------------------------------
# Data set            :     unknown
# Weights matrix      :     unknown
# Dependent Variable  :    ['신고건수']                Number of Observations:          40
# Mean dependent var  :  61535.3250                Number of Variables   :          20
# S.D. dependent var  :  25100.0247                Degrees of Freedom    :          20
# R-squared           :      0.9375
# Adjusted R-squared  :      0.8782
# Sum squared residual:1534522554.731                F-statistic           :     15.8019
# Sigma-square        :76726127.737                Prob(F-statistic)     :   3.522e-08
# S.E. of regression  :    8759.345                Log likelihood        :    -406.010
# Sigma-square ML     :38363063.868                Akaike info criterion :     852.019
# S.E of regression ML:   6193.7924                Schwarz criterion     :     885.797
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     t-Statistic     Probability
# ------------------------------------------------------------------------------------
#             CONSTANT    23504.2678953    9291.3939408       2.5296816       0.0199271
#                 건물연한    -11286.5862506    24978.9517774      -0.4518439       0.6562435
#                건물노후도    -3402.7878554    22283.5742865      -0.1527039       0.8801619
#                 단독주택    987808.8187885    862388.7834418       1.1454333       0.2655516
#                 공동주택    393274.3476529    321130.7920387       1.2246547       0.2349347
#            제2종근린생활시설    155192.2533475    121018.1064471       1.2823887       0.2143713
#            제1종근린생활시설    189255.0113163    127651.7333350       1.4825887       0.1537704
#                   공장    -14500.2526449    12674.7150909      -1.1440299       0.2661196
#                 업무시설    20761.1368645    10901.2554758       1.9044721       0.0713337
#               교육연구시설    3822.2649745    10029.4984734       0.3811023       0.7071456
#                 창고시설    -79806.4085006    24888.7407288      -3.2065266       0.0044297
#                노유자시설    45276.3058365    26766.6864942       1.6915170       0.1062622
#                 숙박시설    1567.2660233    12829.5954646       0.1221602       0.9039913
#               생활관련시설    -1335465.9443684    1127664.3303960      -1.1842761       0.2501876
#                 유흥업소    41134.7535352    13714.5659276       2.9993478       0.0070863
#                  보안등    -7262.8975860    10200.3648738      -0.7120233       0.4846741
#                안전비상벨    25607.6357877    15875.0508477       1.6130743       0.1223966
#            안전비상벨_가로변    -16446.2484569    14029.4407790      -1.1722669       0.2548649
#             안전비상벨_공원    -13159.1458159    12474.8616048      -1.0548531       0.3040696
#            안전비상벨_화장실    7164.6038910    6695.4190733       1.0700755       0.2973302
# ------------------------------------------------------------------------------------
# Warning: Variable(s) ['const'] removed for being constant.
#
# REGRESSION DIAGNOSTICS
# MULTICOLLINEARITY CONDITION NUMBER         1797.261
#
# TEST ON NORMALITY OF ERRORS
# TEST                             DF        VALUE           PROB
# Jarque-Bera                       2           0.354           0.8377
#
# DIAGNOSTICS FOR HETEROSKEDASTICITY
# RANDOM COEFFICIENTS
# TEST                             DF        VALUE           PROB
# Breusch-Pagan test               19          28.397           0.0761
# Koenker-Bassett test             19          26.552           0.1155
#
# SPECIFICATION ROBUST TEST
# Not computed due to multicollinearity.
#
# DIAGNOSTICS FOR SPATIAL DEPENDENCE
# TEST                           MI/DF       VALUE           PROB
# Moran's I (error)             -0.0612         0.207           0.8361
# Lagrange Multiplier (lag)         1           2.869           0.0903
# Robust LM (lag)                   1           3.003           0.0831
# Lagrange Multiplier (error)       1           0.237           0.6266
# Robust LM (error)                 1           0.371           0.5426
# Lagrange Multiplier (SARMA)       2           3.240           0.1979
#
# ================================ END OF REPORT =====================================

# %%
gmerror_Q_ctc = gmerror(half_X, y_df, w) #GMM 추정
# Out:
# REGRESSION
# ----------
# SUMMARY OF OUTPUT: SPATIALLY WEIGHTED LEAST SQUARES
# ---------------------------------------------------
# Data set            :     unknown
# Weights matrix      :     unknown
# Dependent Variable  :    ['신고건수']                Number of Observations:          40
# Mean dependent var  :  61535.3250                Number of Variables   :          20
# S.D. dependent var  :  25100.0247                Degrees of Freedom    :          20
# Pseudo R-squared    :      0.9365
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     z-Statistic     Probability
# ------------------------------------------------------------------------------------
#             CONSTANT    24100.4993297    6346.3460365       3.7975394       0.0001461
#                 건물연한    -8332.1326982    17526.2548494      -0.4754086       0.6344957
#                건물노후도    -4992.4326801    15547.4793411      -0.3211088       0.7481279
#                 단독주택    846770.9298248    599206.8690043       1.4131529       0.1576108
#                 공동주택    337877.6745248    223063.2963324       1.5147166       0.1298442
#            제2종근린생활시설    137589.4753267    84046.0380786       1.6370727       0.1016153
#            제1종근린생활시설    171127.1230674    88567.1601881       1.9321735       0.0533381
#                   공장    -13134.4403442    8852.7454097      -1.4836573       0.1378999
#                 업무시설    18708.3834427    7613.0834236       2.4573990       0.0139947
#               교육연구시설    2509.4564187    6837.4250045       0.3670178       0.7136058
#                 창고시설    -84386.9336876    17170.3094592      -4.9147008       0.0000009
#                노유자시설    52377.2377183    18360.1169180       2.8527726       0.0043340
#                 숙박시설    1884.1378822    9173.5934577       0.2053871       0.8372697
#               생활관련시설    -1156177.3059063    783316.1303655      -1.4760034       0.1399430
#                 유흥업소    40977.6075710    9858.4581712       4.1565939       0.0000323
#                  보안등    -8013.8027730    7136.4055364      -1.1229467       0.2614601
#                안전비상벨    29031.0038148    11194.5298034       2.5933205       0.0095054
#            안전비상벨_가로변    -18800.9683352    9882.0100619      -1.9025449       0.0570999
#             안전비상벨_공원    -13941.3869163    8684.0667886      -1.6053984       0.1084062
#            안전비상벨_화장실    6697.7596793    4668.9321714       1.4345378       0.1514189
#               lambda      -0.1679876
# ------------------------------------------------------------------------------------
# Warning: Variable(s) ['const'] removed for being constant.
# ================================ END OF REPORT =====================================

# %%
gmlag_D_cth = gmlag(half_X, y, w) #2SLS 추정
# Out:
# REGRESSION
# ----------
# SUMMARY OF OUTPUT: SPATIAL TWO STAGE LEAST SQUARES
# --------------------------------------------------
# Data set            :     unknown
# Weights matrix      :     unknown
# Dependent Variable  :     dep_var                Number of Observations:          40
# Mean dependent var  :  61535.3250                Number of Variables   :          21
# S.D. dependent var  :  25100.0247                Degrees of Freedom    :          19
# Pseudo R-squared    :      0.9439
# Spatial Pseudo R-squared:  0.9406
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     z-Statistic     Probability
# ------------------------------------------------------------------------------------
#             CONSTANT    42123.9491103    11014.6345621       3.8243619       0.0001311
#                 건물연한    -21161.2895666    17413.9694264      -1.2151905       0.2242935
#                건물노후도    -969.8455649    14975.2901117      -0.0647631       0.9483627
#                 단독주택    1232759.1575711    589967.4199911       2.0895377       0.0366593
#                 공동주택    492886.4110661    220555.4192968       2.2347509       0.0254337
#            제2종근린생활시설    184910.5314899    82359.1843315       2.2451720       0.0247571
#            제1종근린생활시설    236676.2488123    88592.4428789       2.6715174       0.0075509
#                   공장    -15231.8392925    8498.5088724      -1.7922955       0.0730856
#                 업무시설    20056.5368780    7311.0264590       2.7433271       0.0060820
#               교육연구시설    -2785.9030958    7452.8651395      -0.3738030       0.7085509
#                 창고시설    -79203.1172635    16675.9876450      -4.7495308       0.0000020
#                노유자시설    40697.3734001    18070.1689035       2.2521856       0.0243105
#                 숙박시설    9881.4260010    9504.4564561       1.0396624       0.2984968
#               생활관련시설    -1668994.0699627    772778.9630061      -2.1597302       0.0307936
#                 유흥업소    36562.4103410    9454.7318442       3.8671018       0.0001101
#                  보안등    -2337.9835164    7243.7907573      -0.3227569       0.7468793
#                안전비상벨    26955.6027111    10655.2920352       2.5297854       0.0114132
#            안전비상벨_가로변    -17704.3603819    9418.5938197      -1.8797244       0.0601457
#             안전비상벨_공원    -8349.3459942    8680.5381498      -0.9618466       0.3361267
#            안전비상벨_화장실    9872.1902882    4675.9763985       2.1112575       0.0347502
#            W_dep_var      -0.2678924       0.1307438      -2.0489875       0.0404633
# ------------------------------------------------------------------------------------
# Instrumented: W_dep_var
# Instruments: W_건물노후도, W_건물연한, W_공동주택, W_공장, W_교육연구시설, W_노유자시설, W_단독주택,
#              W_보안등, W_생활관련시설, W_숙박시설, W_안전비상벨, W_안전비상벨_가로변, W_안전비상벨_공원,
#              W_안전비상벨_화장실, W_업무시설, W_유흥업소, W_제1종근린생활시설, W_제2종근린생활시설, W_창고시설
# Warning: Variable(s) ['const'] removed for being constant.
# ================================ END OF REPORT =====================================

# %%
#전역적 Moran's I

mi = Moran(y, w)
mi.I, mi.p_sim
# Out:
# (-0.042048409683158094, 0.467)

# %%
#지역적 Moran's I

mil = Moran_Local(y, w)
mil.Is.shape
# Out:
# (40,)

# %%
idx = mil.p_sim < 0.05
mil.p_sim[idx]
# Out:
# array([], dtype=float64)

# %%
sum(mil.q[idx] == 1), sum(mil.q[idx] == 2), sum(mil.q[idx] == 3), sum(mil.q[idx] == 4)
# Out:
# (0, 0, 0, 0)

# %%
#변수들의 데이터타입 변경

X_a = np.array(half_X)

y_a = np.array(y).reshape(-1,1)

# %%
#격자의 centroid값 저장

#df = gpd.GeoDataFrame(df, geometry=df.geometry)

g_coords = gdf['geometry'].centroid

x_g = g_coords.x
y_g = g_coords.y

g_coords = list(zip(x_g, y_g))

# %%
# GWR 분석 결과

gwr_selector_ctc = Sel_BW(g_coords, y_a, X_a, kernel='gaussian')
gwr_bw_ctc = gwr_selector_ctc.search(bw_min=2)

# %%
gwr_model_ctc = GWR(g_coords, y_a, X_a, gwr_bw_ctc, fixed=False, kernel='gaussian')
gwr_result_ctc = gwr_model_ctc.fit()
gwr_result_ctc.summary()
# Out:
# ===========================================================================
# Model type                                                         Gaussian
# Number of observations:                                                  40
# Number of covariates:                                                    20
#
# Global Regression Results
# ---------------------------------------------------------------------------
# Residual sum of squares:                                       1534522554.731
# Log-likelihood:                                                    -406.010
# AIC:                                                                852.019
# AICc:                                                               905.353
# BIC:                                                           1534522480.953
# R2:                                                                   0.938
# Adj. R2:                                                              0.878
#
# Variable                              Est.         SE  t(Est/SE)    p-value
# ------------------------------- ---------- ---------- ---------- ----------
# X0                               23504.268   9291.394      2.530      0.011
# X1                              -11286.586  24978.952     -0.452      0.651
# X2                               -3402.788  22283.574     -0.153      0.879
# X3                              987808.819 862388.783      1.145      0.252
# X4                              393274.348 321130.792      1.225      0.221
# X5                              155192.253 121018.106      1.282      0.200
# X6                              189255.011 127651.733      1.483      0.138
# X7                              -14500.253  12674.715     -1.144      0.253
# X8                               20761.137  10901.255      1.904      0.057
# X9                                3822.265  10029.498      0.381      0.703
# X10                             -79806.409  24888.741     -3.207      0.001
# X11                              45276.306  26766.686      1.692      0.091
# X12                               1567.266  12829.595      0.122      0.903
# X13                             -1335465.944 1127664.330     -1.184      0.236
# X14                              41134.754  13714.566      2.999      0.003
# X15                              -7262.898  10200.365     -0.712      0.476
# X16                              25607.636  15875.051      1.613      0.107
# X17                             -16446.248  14029.441     -1.172      0.241
# X18                             -13159.146  12474.862     -1.055      0.291
# X19                               7164.604   6695.419      1.070      0.285
#
# Geographically Weighted Regression (GWR) Results
# ---------------------------------------------------------------------------
# Spatial kernel:                                           Adaptive gaussian
# Bandwidth used:                                                      39.000
#
# Diagnostic information
# ---------------------------------------------------------------------------
# Residual sum of squares:                                       1320419003.730
# Effective number of parameters (trace(S)):                           21.238
# Degree of freedom (n - trace(S)):                                    18.762
# Sigma estimate:                                                    8389.011
# Log-likelihood:                                                    -403.004
# AIC:                                                                850.484
# AICc:                                                               912.138
# BIC:                                                                888.040
# R2:                                                                   0.946
# Adjusted R2:                                                          0.882
# Adj. alpha (95%):                                                     0.047
# Adj. critical t value (95%):                                          2.050
#
# Summary Statistics For GWR Parameter Estimates
# ---------------------------------------------------------------------------
# Variable                   Mean        STD        Min     Median        Max
# -------------------- ---------- ---------- ---------- ---------- ----------
# X0                    24786.537   1201.690  21872.303  25284.749  25341.346
# X1                   -16496.098   5843.050 -19033.451 -18954.921  -2536.889
# X2                     -155.576   3936.083  -9737.246   1502.125   1619.010
# X3                   930259.472  68452.922 899240.777 901409.976 1097884.473
# X4                   370862.284  26243.155 359031.057 359798.860 434956.993
# X5                   147000.311   9582.992 142662.426 142961.186 170446.395
# X6                   182135.652   8889.197 178058.566 178389.973 204059.266
# X7                   -14987.649    535.691 -15239.186 -15208.244 -13674.586
# X8                    20113.717    770.122  19772.314  19791.470  21968.188
# X9                     3427.243    285.450   3289.491   3308.690   4116.172
# X10                  -79454.612    865.491 -81659.654 -79090.046 -79028.485
# X11                   44578.226   1301.463  43990.916  44027.391  47696.641
# X12                    4297.853   2984.216  -2830.065   5557.146   5572.588
# X13                  -1262409.628  87300.824 -1476398.498 -1225611.370 -1222780.343
# X14                   40312.584    812.743  39941.282  39975.475  42277.099
# X15                   -7510.824    224.700  -7635.309  -7600.485  -6957.255
# X16                   27697.727   2109.236  22651.664  28583.350  28596.935
# X17                  -17841.209   1380.304 -18428.658 -18422.773 -14547.123
# X18                  -13918.466    756.273 -14241.226 -14237.665 -12113.839
# X19                    6837.136    263.597   6724.215   6726.127   7466.440
# ===========================================================================

# %%
pd.DataFrame(gwr_result_ctc.y_bar).to_csv('pred_ctc.csv')

# %%
#모델별 R2 분포 확인

plt.figure(figsize=(20, 20))
plt.boxplot([gwr_result_ctc.localR2.reshape(-1,)],
            vert=False, notch=True, sym="")
plt.gca().set_yticklabels(['gwr_ctc'],
                          rotation=0, fontsize=20)
# Out:
# [Text(0, 1, 'gwr_ctc')]

# %%
#차대차 사고의 변수계수 분포

plt.figure(figsize=(20, 20))

plt.boxplot(
    [gwr_result_ctc.params[:,0], gwr_result_ctc.params[:,1], gwr_result_ctc.params[:,2], gwr_result_ctc.params[:,3],
     gwr_result_ctc.params[:,4], gwr_result_ctc.params[:,5], gwr_result_ctc.params[:,6], gwr_result_ctc.params[:,7],
     gwr_result_ctc.params[:,8], gwr_result_ctc.params[:,9], gwr_result_ctc.params[:,10], gwr_result_ctc.params[:,11],
     gwr_result_ctc.params[:,12], gwr_result_ctc.params[:,13], gwr_result_ctc.params[:,14], gwr_result_ctc.params[:,15],
     gwr_result_ctc.params[:,16], gwr_result_ctc.params[:,17], gwr_result_ctc.params[:,18], gwr_result_ctc.params[:,19],],
    vert=False,
    notch=True,
    sym="",
    whis=0.1)

plt.gca().set_yticklabels(list(half_X.columns),
                          rotation=0, fontsize=20)

plt.axvline(0, 0, 1, color='grey', linewidth='1')
